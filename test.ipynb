# %%
import util
import datetime

# %%
start_date = datetime.date(2000, 1, 1)
end_date = datetime.date(2022, 4, 1)
price = util.get_price('HK.00316', start_date, end_date)
# Out:
# 2022-04-18 14:01:52,754 [open_context_base.py] _socket_reconnect_and_wait_ready:258: Start connecting: host=hv2; port=11111;
# 2022-04-18 14:01:52,772 [open_context_base.py] on_connected:347: Connected : conn_id=1;
# 2022-04-18 14:01:52,834 [open_context_base.py] _handle_init_connect:452: InitConnect ok: conn_id=1; info={'server_version': 215, 'login_user_id': 14567428, 'conn_id': 6921699302944752630, 'conn_key': '59515126179634CD', 'conn_iv': '859F4D20013F27B5', 'keep_alive_interval': 10, 'is_encrypt': False};
# 2022-04-18 14:01:53,631 [network_manager.py] work:366: Close: conn_id=1

# %%
price.plot()

# %%
import matplotlib.pyplot as plt

# %%
plt.show()
